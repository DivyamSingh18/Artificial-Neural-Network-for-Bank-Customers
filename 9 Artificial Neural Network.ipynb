# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset["Exited"].sum()  # data is imbalanced
# Out:
# 2037

# %%
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
#Create dummy variables / one hot encoding
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
gender
# Out:
#       Male
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9995     1
# 9996     1
# 9997     0
# 9998     1
# 9999     0
#
# [10000 rows x 1 columns]

# %%
## Concatenate the Data Frames
X=pd.concat([X,geography,gender],axis=1)

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
# ...

# %%
## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler # scaling is only performed on independent features 
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# We use fit_transform() on the train data so that we learn the parameters of scaling on the train data and in the same time we scale the train data. We only use transform() on the test data because we use the scaling paramaters learned on the train data to scale the test data.

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %% [markdown]
# #  Now let's make the ANN!

# %%
# pip install keras

# %%
# !pip install tensorflow
# Out:
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# ...

# %%
import keras    # or use tensorflow.keras 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer='he_uniform',activation='relu',input_dim = 11))

# %%
# activation functions sends the required data to the next layer of neurons  
# units: dimensionality of the output space/ number of neurons that will be present in the respective layer
# kernel_initializer: Initializer for the kernel weights matrix.

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# sigmoid function gives output between 0 and 1

# %%
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7875 - val_loss: 0.5030 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4935 - accuracy: 0.7964 - val_loss: 0.4808 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4772 - accuracy: 0.7962 - val_loss: 0.4691 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4670 - accuracy: 0.7962 - val_loss: 0.4614 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4592 - accuracy: 0.7962 - val_loss: 0.4553 - val_accuracy: 0.7955
# Epoch 6/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4532 - accuracy: 0.7962 - val_loss: 0.4511 - val_accuracy: 0.7955
# Epoch 7/100
# ...

# %%
# list all data in history
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.figure(figsize=(15,7))
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.figure(figsize=(15,7))
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Making the predictions and evaluating the model

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([[0.33783597],
#        [0.33359182],
#        [0.14689082],
#        ...,
#        [0.21444508],
#        [0.12338164],
#        [0.20993784]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# prediction for one data point
print(classifier.predict(sc.transform([[]])) > 0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-2850f65a95f9> in <module>
#       1 # prediction for one data point
# ----> 2 print(classifier.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1,50000]])) > 0.5)
#
# C:\ProgramData\Anaconda3\envs\test\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#     881
#     882         copy = copy if copy is not None else self.copy
# --> 883         X = self._validate_data(X, reset=False,
#     884                                 accept_sparse='csr', copy=copy,
#     885                                 estimator=self, dtype=FLOAT_DTYPES,
#
# C:\ProgramData\Anaconda3\envs\test\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     435
#     436         if check_params.get('ensure_2d', True):
# ...

# %%
#Saving created neural network
classifier.save("ANN.h5")
