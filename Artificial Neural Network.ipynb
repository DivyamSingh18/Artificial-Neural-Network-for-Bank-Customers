# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
dataset["Exited"].sum()  # data is imbalanced
# Out:
# 2037

# %%
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
#Create dummy variables / one hot encoding
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
gender
# Out:
#       Male
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9995     1
# 9996     1
# 9997     0
# 9998     1
# 9999     0
#
# [10000 rows x 1 columns]

# %%
## Concatenate the Data Frames
X=pd.concat([X,geography,gender],axis=1)

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0             1               1        101348.88        0      0     0
# 1             0               1        112542.58        0      1     0
# 2             1               0        113931.57        0      0     0
# 3             0               0         93826.63        0      0     0
# 4             1               1         79084.10        0      1     0
# ...         ...             ...              ...      ...    ...   ...
# 9995          1               0         96270.64        0      0     1
# 9996          1               1        101699.77        0      0     1
# 9997          0               1         42085.58        0      0     0
# 9998          1               0         92888.52        1      0     1
# 9999          1               0         38190.78        0      0     0
#
# [10000 rows x 13 columns]

# %%
## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# 1                  1        112542.58        0      1     0
# 2                  0        113931.57        0      0     0
# 3                  0         93826.63        0      0     0
# 4                  1         79084.10        0      1     0
# ...              ...              ...      ...    ...   ...
# 9995               0         96270.64        0      0     1
# 9996               1        101699.77        0      0     1
# 9997               1         42085.58        0      0     0
# 9998               0         92888.52        1      0     1
# 9999               0         38190.78        0      0     0
#
# [10000 rows x 11 columns]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_test
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9394          597   35       8  131101.04              1          1
# 898           523   40       2  102967.41              1          1
# 2398          706   42       8   95386.82              1          1
# 5906          788   32       4  112079.58              1          0
# 2343          706   38       5  163034.82              2          1
# ...           ...  ...     ...        ...            ...        ...
# 1037          625   24       1       0.00              2          1
# 2899          586   35       7       0.00              2          1
# 9549          578   36       1  157267.95              2          1
# 2740          650   34       4  142393.11              1          1
# 6690          573   30       8  127406.50              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 9394               1        192852.67        1      0     0
# 898                0        128702.10        0      0     0
# 2398               1         75732.25        0      1     0
# 5906               0         89368.59        0      0     1
# 2343               1        135662.17        1      0     1
# ...              ...              ...      ...    ...   ...
# 1037               1        180969.55        0      0     0
# 2899               0         70760.69        0      0     0
# 9549               0        141533.19        0      1     1
# 2740               1         11276.48        1      0     1
# 6690               0        192950.60        1      0     1
#
# [2000 rows x 11 columns]

# %%
y_test
# Out:
# 9394    0
# 898     1
# 2398    0
# 5906    0
# 2343    0
#        ..
# 1037    0
# 2899    0
# 9549    0
# 2740    0
# 6690    0
# Name: Exited, Length: 2000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler # scaling is only performed on independent features 
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# We use fit_transform() on the train data so that we learn the parameters of scaling on the train data and in the same time we scale the train data. We only use transform() on the test data because we use the scaling paramaters learned on the train data to scale the test data.

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %% [markdown]
# #  Now let's make the ANN!

# %%
# pip install keras

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\programdata\anaconda3\envs\test\lib\site-packages (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from tensorflow) (3.10.0.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: six>=1.12.0 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: gast>=0.2.1 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: flatbuffers>=1.12 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\envs\test\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\envs\test\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\envs\test\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\envs\test\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\test\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\envs\test\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divyam singh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\envs\test\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\divyam singh\appdata\roaming\python\python39\site-packages)

# %%
import keras    # or use tensorflow.keras 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer='he_uniform',activation='relu',input_dim = 11))

# %%
# activation functions sends the required data to the next layer of neurons  
# units: dimensionality of the output space/ number of neurons that will be present in the respective layer
# kernel_initializer: Initializer for the kernel weights matrix.

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# sigmoid function gives output between 0 and 1

# %%
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 2ms/step - loss: 0.6887 - accuracy: 0.6022 - val_loss: 0.5722 - val_accuracy: 0.7861
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7951 - val_loss: 0.5023 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4902 - accuracy: 0.7962 - val_loss: 0.4801 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4734 - accuracy: 0.7962 - val_loss: 0.4710 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4640 - accuracy: 0.7962 - val_loss: 0.4644 - val_accuracy: 0.7955
# Epoch 6/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4565 - accuracy: 0.7962 - val_loss: 0.4584 - val_accuracy: 0.7955
# Epoch 7/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4503 - accuracy: 0.7962 - val_loss: 0.4536 - val_accuracy: 0.7955
# Epoch 8/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4444 - accuracy: 0.7962 - val_loss: 0.4490 - val_accuracy: 0.7955
# Epoch 9/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4391 - accuracy: 0.7962 - val_loss: 0.4452 - val_accuracy: 0.7955
# Epoch 10/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4345 - accuracy: 0.7962 - val_loss: 0.4417 - val_accuracy: 0.7955
# Epoch 11/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4302 - accuracy: 0.7962 - val_loss: 0.4380 - val_accuracy: 0.7955
# Epoch 12/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4263 - accuracy: 0.7962 - val_loss: 0.4352 - val_accuracy: 0.7955
# Epoch 13/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4229 - accuracy: 0.7962 - val_loss: 0.4324 - val_accuracy: 0.7955
# Epoch 14/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.7964 - val_loss: 0.4297 - val_accuracy: 0.7955
# Epoch 15/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4161 - accuracy: 0.7966 - val_loss: 0.4271 - val_accuracy: 0.7948
# Epoch 16/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4130 - accuracy: 0.7983 - val_loss: 0.4245 - val_accuracy: 0.7978
# Epoch 17/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4101 - accuracy: 0.8024 - val_loss: 0.4220 - val_accuracy: 0.7997
# Epoch 18/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4073 - accuracy: 0.8052 - val_loss: 0.4198 - val_accuracy: 0.8042
# Epoch 19/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4047 - accuracy: 0.8097 - val_loss: 0.4177 - val_accuracy: 0.8092
# Epoch 20/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4025 - accuracy: 0.8138 - val_loss: 0.4163 - val_accuracy: 0.8111
# Epoch 21/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4004 - accuracy: 0.8147 - val_loss: 0.4144 - val_accuracy: 0.8103
# Epoch 22/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3984 - accuracy: 0.8156 - val_loss: 0.4125 - val_accuracy: 0.8107
# Epoch 23/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3963 - accuracy: 0.8171 - val_loss: 0.4108 - val_accuracy: 0.8137
# Epoch 24/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3944 - accuracy: 0.8160 - val_loss: 0.4088 - val_accuracy: 0.8137
# Epoch 25/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3924 - accuracy: 0.8164 - val_loss: 0.4072 - val_accuracy: 0.8148
# Epoch 26/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3905 - accuracy: 0.8169 - val_loss: 0.4057 - val_accuracy: 0.8156
# Epoch 27/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3885 - accuracy: 0.8169 - val_loss: 0.4044 - val_accuracy: 0.8160
# Epoch 28/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3866 - accuracy: 0.8181 - val_loss: 0.4025 - val_accuracy: 0.8183
# Epoch 29/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3847 - accuracy: 0.8184 - val_loss: 0.4010 - val_accuracy: 0.8194
# Epoch 30/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3830 - accuracy: 0.8203 - val_loss: 0.3997 - val_accuracy: 0.8209
# Epoch 31/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3814 - accuracy: 0.8207 - val_loss: 0.3987 - val_accuracy: 0.8209
# Epoch 32/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3799 - accuracy: 0.8203 - val_loss: 0.3973 - val_accuracy: 0.8224
# Epoch 33/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3782 - accuracy: 0.8212 - val_loss: 0.3960 - val_accuracy: 0.8217
# Epoch 34/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3768 - accuracy: 0.8205 - val_loss: 0.3947 - val_accuracy: 0.8228
# Epoch 35/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3755 - accuracy: 0.8205 - val_loss: 0.3938 - val_accuracy: 0.8228
# Epoch 36/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3741 - accuracy: 0.8214 - val_loss: 0.3927 - val_accuracy: 0.8220
# Epoch 37/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3728 - accuracy: 0.8222 - val_loss: 0.3918 - val_accuracy: 0.8217
# Epoch 38/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3715 - accuracy: 0.8296 - val_loss: 0.3906 - val_accuracy: 0.8372
# Epoch 39/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3703 - accuracy: 0.8378 - val_loss: 0.3896 - val_accuracy: 0.8360
# Epoch 40/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3690 - accuracy: 0.8393 - val_loss: 0.3888 - val_accuracy: 0.8368
# Epoch 41/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3678 - accuracy: 0.8416 - val_loss: 0.3881 - val_accuracy: 0.8349
# Epoch 42/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3666 - accuracy: 0.8414 - val_loss: 0.3872 - val_accuracy: 0.8357
# Epoch 43/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3655 - accuracy: 0.8427 - val_loss: 0.3866 - val_accuracy: 0.8368
# Epoch 44/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3644 - accuracy: 0.8440 - val_loss: 0.3861 - val_accuracy: 0.8372
# Epoch 45/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3635 - accuracy: 0.8444 - val_loss: 0.3852 - val_accuracy: 0.8383
# Epoch 46/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3625 - accuracy: 0.8462 - val_loss: 0.3845 - val_accuracy: 0.8383
# Epoch 47/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3617 - accuracy: 0.8457 - val_loss: 0.3840 - val_accuracy: 0.8372
# Epoch 48/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3608 - accuracy: 0.8457 - val_loss: 0.3831 - val_accuracy: 0.8421
# Epoch 49/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3601 - accuracy: 0.8483 - val_loss: 0.3826 - val_accuracy: 0.8413
# Epoch 50/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3593 - accuracy: 0.8513 - val_loss: 0.3820 - val_accuracy: 0.8406
# Epoch 51/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8498 - val_loss: 0.3815 - val_accuracy: 0.8417
# Epoch 52/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3578 - accuracy: 0.8511 - val_loss: 0.3803 - val_accuracy: 0.8436
# Epoch 53/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3571 - accuracy: 0.8528 - val_loss: 0.3798 - val_accuracy: 0.8432
# Epoch 54/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3564 - accuracy: 0.8528 - val_loss: 0.3791 - val_accuracy: 0.8421
# Epoch 55/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3556 - accuracy: 0.8531 - val_loss: 0.3784 - val_accuracy: 0.8436
# Epoch 56/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3550 - accuracy: 0.8530 - val_loss: 0.3777 - val_accuracy: 0.8444
# Epoch 57/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3544 - accuracy: 0.8537 - val_loss: 0.3771 - val_accuracy: 0.8474
# Epoch 58/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3538 - accuracy: 0.8552 - val_loss: 0.3767 - val_accuracy: 0.8463
# Epoch 59/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3532 - accuracy: 0.8559 - val_loss: 0.3760 - val_accuracy: 0.8463
# Epoch 60/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3526 - accuracy: 0.8561 - val_loss: 0.3753 - val_accuracy: 0.8466
# Epoch 61/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3520 - accuracy: 0.8580 - val_loss: 0.3747 - val_accuracy: 0.8482
# Epoch 62/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3514 - accuracy: 0.8569 - val_loss: 0.3741 - val_accuracy: 0.8482
# Epoch 63/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3508 - accuracy: 0.8576 - val_loss: 0.3738 - val_accuracy: 0.8474
# Epoch 64/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3503 - accuracy: 0.8571 - val_loss: 0.3734 - val_accuracy: 0.8497
# Epoch 65/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3498 - accuracy: 0.8582 - val_loss: 0.3727 - val_accuracy: 0.8482
# Epoch 66/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3495 - accuracy: 0.8578 - val_loss: 0.3724 - val_accuracy: 0.8493
# Epoch 67/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3491 - accuracy: 0.8587 - val_loss: 0.3721 - val_accuracy: 0.8504
# Epoch 68/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3485 - accuracy: 0.8589 - val_loss: 0.3720 - val_accuracy: 0.8508
# Epoch 69/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3482 - accuracy: 0.8589 - val_loss: 0.3714 - val_accuracy: 0.8508
# Epoch 70/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3479 - accuracy: 0.8597 - val_loss: 0.3711 - val_accuracy: 0.8508
# Epoch 71/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3472 - accuracy: 0.8600 - val_loss: 0.3713 - val_accuracy: 0.8478
# Epoch 72/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3471 - accuracy: 0.8599 - val_loss: 0.3706 - val_accuracy: 0.8527
# Epoch 73/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3467 - accuracy: 0.8593 - val_loss: 0.3704 - val_accuracy: 0.8519
# Epoch 74/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3464 - accuracy: 0.8599 - val_loss: 0.3697 - val_accuracy: 0.8535
# Epoch 75/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3458 - accuracy: 0.8600 - val_loss: 0.3696 - val_accuracy: 0.8516
# Epoch 76/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3455 - accuracy: 0.8608 - val_loss: 0.3693 - val_accuracy: 0.8516
# Epoch 77/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3453 - accuracy: 0.8610 - val_loss: 0.3690 - val_accuracy: 0.8527
# Epoch 78/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3448 - accuracy: 0.8608 - val_loss: 0.3691 - val_accuracy: 0.8519
# Epoch 79/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3445 - accuracy: 0.8610 - val_loss: 0.3686 - val_accuracy: 0.8508
# Epoch 80/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3443 - accuracy: 0.8604 - val_loss: 0.3689 - val_accuracy: 0.8504
# Epoch 81/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3441 - accuracy: 0.8599 - val_loss: 0.3681 - val_accuracy: 0.8516
# Epoch 82/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3438 - accuracy: 0.8623 - val_loss: 0.3678 - val_accuracy: 0.8523
# Epoch 83/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3435 - accuracy: 0.8608 - val_loss: 0.3677 - val_accuracy: 0.8523
# Epoch 84/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3434 - accuracy: 0.8612 - val_loss: 0.3673 - val_accuracy: 0.8531
# Epoch 85/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3430 - accuracy: 0.8619 - val_loss: 0.3674 - val_accuracy: 0.8504
# Epoch 86/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3428 - accuracy: 0.8625 - val_loss: 0.3670 - val_accuracy: 0.8527
# Epoch 87/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3426 - accuracy: 0.8625 - val_loss: 0.3667 - val_accuracy: 0.8519
# Epoch 88/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3424 - accuracy: 0.8610 - val_loss: 0.3665 - val_accuracy: 0.8527
# Epoch 89/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3423 - accuracy: 0.8619 - val_loss: 0.3662 - val_accuracy: 0.8508
# Epoch 90/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3420 - accuracy: 0.8617 - val_loss: 0.3660 - val_accuracy: 0.8516
# Epoch 91/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3418 - accuracy: 0.8621 - val_loss: 0.3656 - val_accuracy: 0.8508
# Epoch 92/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3416 - accuracy: 0.8625 - val_loss: 0.3653 - val_accuracy: 0.8546
# Epoch 93/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3413 - accuracy: 0.8610 - val_loss: 0.3650 - val_accuracy: 0.8512
# Epoch 94/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3412 - accuracy: 0.8619 - val_loss: 0.3648 - val_accuracy: 0.8565
# Epoch 95/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3409 - accuracy: 0.8621 - val_loss: 0.3650 - val_accuracy: 0.8519
# Epoch 96/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3409 - accuracy: 0.8615 - val_loss: 0.3644 - val_accuracy: 0.8527
# Epoch 97/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3404 - accuracy: 0.8621 - val_loss: 0.3644 - val_accuracy: 0.8561
# Epoch 98/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3402 - accuracy: 0.8608 - val_loss: 0.3648 - val_accuracy: 0.8519
# Epoch 99/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.8617 - val_loss: 0.3638 - val_accuracy: 0.8565
# Epoch 100/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3402 - accuracy: 0.8619 - val_loss: 0.3638 - val_accuracy: 0.8565

# %%
# list all data in history
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.figure(figsize=(15,7))
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.figure(figsize=(15,7))
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Making the predictions and evaluating the model

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([[0.24677181],
#        [0.33614004],
#        [0.1376344 ],
#        ...,
#        [0.30750167],
#        [0.16732517],
#        [0.16698259]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# prediction for one data point
inp = classifier.predict(sc.transform([[597,35,8,131101.04,1,1,1,192852.67,1,0,0]]))
print(inp)
ans = classifier.predict(sc.transform([[788,32,4,112079.58,1,0,0,89368.59,0,0,1]])) > 0.5
print(ans)
if ans == False:
    print("Person wont leave")
else:
    print("Person may leave ")
# Out:
# [[0.2467719]]
# [[False]]
# Person wont leave

# %%
#Saving created neural network
classifier.save("ANN.h5")
